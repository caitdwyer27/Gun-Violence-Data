# %% [markdown]
# **Gun Violence Data: Filtered**

# %% [markdown]
# Overview: Starting from a large compliled data set of gun violence statistics throughout the United States, we want to filter down to the data of only one state.

# %% [markdown]
# **Step 1**: First, you will need to mount your google drive in order to eventually pull csv files from.
#
#       Use the following code.
#
#       It will display a pop up asking if you would like to allow this action; click allow.

# %%
from google.colab import drive
drive.mount ('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Step 2:** Once you see the green check mark on the side, import numpy and pandas in order to manipulate the data.
#
#     We code numpy as np and pandas as pd in order to simplify the codes later on.
#
#     Use the following codes to import:

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# **Step 3:** Importing the csv file
#
#     Download the csv file, "stage3.csv", to your google drive.
#
#     Within google drive, move the csv to the colab notebook file.
#
#     Use the following code to import the csv file, allowing it to be deciphered:

# %%
df= pd.read_csv('gdrive/My Drive/Colab Notebooks/stage3.csv')

# %% [markdown]
# **Step 4:** Finally, organize the data by state
#
#     Choose one state, in this case Pennsylvania,to filter the data set into a smaller subset
#
#     Use the follwing code to do so:

# %%
df[df["state"] == "Pennsylvania"]
# Out:
#         incident_id        date         state city_or_county  \
# 0            461105  2013-01-01  Pennsylvania     Mckeesport
# 49           484268  2013-04-09  Pennsylvania   Philadelphia
# 61           485885  2013-04-28  Pennsylvania        Chester
# 67           486068  2013-05-06  Pennsylvania      Johnstown
# 70           486121  2013-05-11  Pennsylvania   Philadelphia
# ...             ...         ...           ...            ...
# 239584      1082035  2018-03-31  Pennsylvania   Philadelphia
# 239607      1081666  2018-03-31  Pennsylvania           York
# 239614      1082682  2018-03-31  Pennsylvania         Easton
# 239616      1082652  2018-03-31  Pennsylvania         Easton
# 239646      1082455  2018-03-31  Pennsylvania       Duquesne
#
#                                           address  n_killed  n_injured  \
# 0       1506 Versailles Avenue and Coursin Street         0          4
# 49                 Somerset Street and Lee Street         1          3
# ...
